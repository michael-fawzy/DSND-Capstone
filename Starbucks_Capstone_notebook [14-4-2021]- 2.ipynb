# %% [markdown]
# # Starbucks Capstone Challenge
#
# ## Table of contents
#
# [1. Introduction](#intro)
#
# [2. Problem Statement](#statement)
#   * [A. Strategy](#strategy)
#   * [B. Metrics](#metrics)
#   * [C. Refinement](#refinement)
#
# [3. Data Sets](#data)
#   * [A. Portfolio.json](#portfolio)
#
#   * [B. Profile.json](#profile)
#
#   * [C. Transcript.json](#transcript)
#
#
# [4. Data Analysis](#analysis)
#
#   * [Data Exploration & Visualization](#exploaration)
#
#       * [A. Portfolio.json](#portfolio_analysis)
#
#       * [B. Profile.json](#profile_analysis)
#
#       * [C. Transcript.json](#transcript_analysis)
#
#
# [5. Methodology](#methodology)
#   * [A. Data Preprocessing](#preprocessing)
#   * [B. Storing Data](#storing)
#
#   * [C. Implementation](#implementation)
#
#   * [D. Refinement](#refining)
#
# [6. Results](#results)
#   * [A. Answering Questions](#answering)
#
#   * [B. Justification](#justification)
#
#
# [7. Conclusion](#conclusion)
#   * [A. Reflection](#reflection)
#
#   * [B. Improvement](#improvement)

# %% [markdown]
# <a id='intro'></a>
# ## 1. Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# A. In a *BOGO offer*, a user needs to spend a certain amount to get a reward equal to that threshold amount.
#
# B. In a *discount*, a user gains a reward equal to a fraction of the amount spent.
#
# C. In an *informational offer*, there is no reward, but **neither** is there a requisite amount that the user is expected to spend. Offers can be delivered via multiple channels.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# The program used to create the data simulates how people make purchasing decisions and how those decisions are influenced by promotional offers.
#
# Each person in the simulation has some hidden traits that influence their purchasing patterns and are associated with their observable traits. People produce various events, including receiving offers, opening offers, and making purchases.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has **one** product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. *You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.*
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (i.e., 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# <a id='statement'></a>
# ## 2. Problem Statement
#
# The basic task is to use the data to identify which groups of people are most responsive to each type of offer (and how best to present each type of offer).
#
# <a id='strategy '></a>
# ### A. Strategy
# 1- Combine transaction, demographic and offer data.
#
# 2- Determine which demographic groups respond best to which offer type.
#
# 3- May be we can check the number/percent of offers completed withouth viewing.
#
# 4- How best to present each type of offer.
#
# 5- Try to assess what a certain demographic group will buy when not receiving any offers so you won't send them any.
#
# <a id='metrics'></a>
# ### B. Metrics
# Response is measured by number of completed offers and/or transacion.
#
# <a id='refinement'></a>
# ### C. Refinement
# May be we can first show results of gender and age, then refine by adding income..
# Or just anything similar.

# %% [markdown]
# <a id='data'></a>
#
# ## 3. Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# <a id='portfolio'></a>
# ### A. Portfolio.json
#
# Offers sent during 30-day test period (10 offers x 6 fields)
#
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational (an advertisement for a drink).
# * difficulty (int) - minimum  money required to be spent to complete an offer and receive reward.
# * reward (int) - reward given for completing an offer (money awarded for the amount spent).
# * duration (int) - time for offer to be open, in days.
# * channels (list of strings) - web, email, mobile, social.
#
# <a id='profile'></a>
# ### B. Profile.json
#
# Rewards program users (17000 users x 5 fields)
#
# * age (int) - age of the customer. Missing value encoded as 118
# * became_member_on (int) - date when customer created an app account (date format YYYYMMDD)
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# <a id='transcript'></a>
# ### C. Transcript.json
#
# Event log (306648 events x 4 fields)
#
# * event (str) - record description (ie transaction, offer received, offer viewed, offer completed).
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - different values depending on event type:
#     - offer id: (string/hash) not associated with any "transaction"
#     - amount: (numeric) money spent in "transaction"
#     - reward: (numeric) money gained from "offer completed"
#
# **Note:** If you are using the workspace, you will need to go to the terminal and run the command `conda update pandas` before reading in the files. This is because the version of pandas in the workspace cannot read in the transcript.json file correctly, but the newest version of pandas can. You can access the termnal from the orange icon in the top left of this notebook.
#
# You can see how to access the terminal and how the install works using the two images below.  First you need to access the terminal:
#
# <img src="pic1.png"/>
#
# Then you will want to run the above command:
#
# <img src="pic2.png"/>
#
# Finally, when you enter back into the notebook (use the jupyter icon again), you should be able to run the below cell without any errors.

# %% [markdown]
# <a id='analysis'></a>
# ## 4. Data Analysis
# <a id='exploaration'></a>
# ### Data Exploration & Visualization

# %%
# Import Libraries
import pandas as pd
import numpy as np
import math
import json
import matplotlib.pyplot as plt
import seaborn as sb
% matplotlib inline

# Read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %% [markdown]
# <a id='portfolio_analysis'></a>
# #### A. Portfolio.json

# %%
portfolio.shape
# Out:
# (10, 6)

# %%
portfolio.head(10)
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
# 5  [web, email, mobile, social]           7         7
# 6  [web, email, mobile, social]          10        10
# 7       [email, mobile, social]           0         3
# 8  [web, email, mobile, social]           5         5
# 9          [web, email, mobile]          10         7
#
#                                  id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       discount       3
# 6  fafdcd668e3743c1bb461111dcafc2a4       discount       2
# 7  5a8bc65990b245e5a138643cd4eb9837  informational       0
# 8  f19421c1d4aa40978ebb69ca19b0e20d           bogo       5
# 9  2906b810c7d4411798c6938adc9daaa5       discount       2

# %%
portfolio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
# channels      10 non-null object
# difficulty    10 non-null int64
# duration      10 non-null int64
# id            10 non-null object
# offer_type    10 non-null object
# reward        10 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 560.0+ bytes

# %%
portfolio.describe()
# Out:
#        difficulty   duration     reward
# count   10.000000  10.000000  10.000000
# mean     7.700000   6.500000   4.200000
# std      5.831905   2.321398   3.583915
# min      0.000000   3.000000   0.000000
# 25%      5.000000   5.000000   2.000000
# 50%      8.500000   7.000000   4.000000
# 75%     10.000000   7.000000   5.000000
# max     20.000000  10.000000  10.000000

# %%
portfolio.offer_type.value_counts()
# Out:
# bogo             4
# discount         4
# informational    2
# Name: offer_type, dtype: int64

# %%
portfolio.hist(figsize= (15,12));  #histogram of whole dataset

# %% [markdown]
# *Every thing looks good. No cleaning required.*

# %% [markdown]
# <a id='profile_analysis'></a>
# #### B. Profile.json

# %%
profile.head() # Remember to check for duplicates
# Out:
#    age  became_member_on gender                                id    income
# 0  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783       NaN
# 1   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 2  118          20180712   None  38fe809add3b4fcf9315a9694bb96ff5       NaN
# 3   75          20170509      F  78afa995795e4d85b5d9ceeca43f5fef  100000.0
# 4  118          20170804   None  a03223e636434f42ac4c3df47e8bac43       NaN

# %%
profile.shape
# Out:
# (17000, 5)

# %%
profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 5 columns):
# age                 17000 non-null int64
# became_member_on    17000 non-null int64
# gender              14825 non-null object
# id                  17000 non-null object
# income              14825 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 664.1+ KB

# %% [markdown]
# *Same number of missing gender & income values. Those probably belong to customers of unknown age (118)*

# %%
profile.describe()
# Out:
#                 age  became_member_on         income
# count  17000.000000      1.700000e+04   14825.000000
# mean      62.531412      2.016703e+07   65404.991568
# std       26.738580      1.167750e+04   21598.299410
# min       18.000000      2.013073e+07   30000.000000
# 25%       45.000000      2.016053e+07   49000.000000
# 50%       58.000000      2.017080e+07   64000.000000
# 75%       73.000000      2.017123e+07   80000.000000
# max      118.000000      2.018073e+07  120000.000000

# %%
profile.hist(figsize= (15,12));  #histogram of whole dataset

# %% [markdown]
# - Age of most customers  falls between 50 and 70 years.
# - Most customers beacme members between 2017 & 2018.
# - Income of most customers falls between 50,000 and 75,000.
#
# **So, do purchases and response to offers correspond to these results?**

# %%
profile[profile.isna().any(axis=1)]
# Out:
#        age  became_member_on gender                                id  income
# 0      118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783     NaN
# 2      118          20180712   None  38fe809add3b4fcf9315a9694bb96ff5     NaN
# 4      118          20170804   None  a03223e636434f42ac4c3df47e8bac43     NaN
# 6      118          20170925   None  8ec6ce2a7e7949b1bf142def7d0e0586     NaN
# 7      118          20171002   None  68617ca6246f4fbc85e91a2a49552598     NaN
# 9      118          20161122   None  8974fc5686fe429db53ddde067b88302     NaN
# 10     118          20170824   None  c4863c7985cf408faee930f111475da3     NaN
# 11     118          20150919   None  148adfcaa27d485b82f323aaaad036bd     NaN
# 17     118          20170801   None  744d603ef08c4f33af5a61c8c7628d1c     NaN
# 23     118          20170907   None  2b826eba31074a059d63b0ae8f50b7d5     NaN
# 26     118          20170330   None  65aba5c617294649aeb624da249e1ee5     NaN
# 36     118          20160707   None  4beeb3ed64dd4898b0edf2f6b67426d3     NaN
# 39     118          20180113   None  25c906289d154b66bf579693f89481c9     NaN
# 44     118          20141111   None  5b8f1f0e0930464f93bb55e59b5a04e0     NaN
# 45     118          20170511   None  8be4463721e14d7fa600686bf8c8b2ed     NaN
# 54     118          20170528   None  81ac76e4f2fe4a6bb5ebdc0f19cecc56     NaN
# 56     118          20171013   None  020d3a52b9ce432ea5f98fc58e9bfcc4     NaN
# 57     118          20151220   None  4be1127413db496d8103c783ae72058b     NaN
# 80     118          20170918   None  9d8d6bb2fc544a9c802888971ee3e8b1     NaN
# 84     118          20150920   None  a89752cdfdf24779aa22faa2bc24e7c2     NaN
# 96     118          20160806   None  53bac762af27471eb294ff89ca1bae2c     NaN
# 103    118          20170223   None  488773cae11f4b71875bfccd4e3e99f2     NaN
# 104    118          20170823   None  182e68952b474700b171e21b85c258ac     NaN
# 108    118          20160130   None  5e9c83e8ab4d4e9ca83f3256d83ca756     NaN
# 121    118          20150730   None  c099206f76b1414db7552f163520053c     NaN
# 122    118          20171125   None  e6d3eebb535e44aca1323edde5c346fa     NaN
# 128    118          20160418   None  baba98dba43e42ae8e86cbd70725e201     NaN
# 143    118          20161018   None  58748c1cf9f746838c6ec62acdff28ad     NaN
# 169    118          20150905   None  770df32893694100afc703ea9c9df401     NaN
# 172    118          20180114   None  50b92ea51e2649dfbf7120d5e554e991     NaN
# ...    ...               ...    ...                               ...     ...
# 16820  118          20151015   None  64257cb56316491fae38e62f2687a66c     NaN
# 16829  118          20171007   None  56a0b671fa0347beb8b60011a15800aa     NaN
# 16831  118          20170910   None  060c0b9181674d03aa181b75353b9422     NaN
# 16835  118          20161211   None  587453e2944b4c6699519a217bf87de6     NaN
# 16839  118          20180626   None  d6063a30185b4e60b58a445bacec5f56     NaN
# 16842  118          20151110   None  a225189b10a141d5bb1ff0a05265da4c     NaN
# 16844  118          20170228   None  4342cb3414534aaca96ac523edc82654     NaN
# 16845  118          20150815   None  d1477e69857f42d18929f6f29b3be427     NaN
# 16852  118          20140605   None  6c0df9b1d3b8401c8098c7c7f9977d89     NaN
# 16853  118          20171123   None  7b3b8100d6444861803cefc6b13c9a43     NaN
# 16856  118          20150729   None  3a02d786fbc143edb257665ad54c5c09     NaN
# 16861  118          20171212   None  8f4364144e0548f885b390f28aabe2b8     NaN
# 16869  118          20160607   None  1efb4a45f5c34db4b07ebd19bdfc1b41     NaN
# 16875  118          20170129   None  113f3f07ac2b4f8b940d6136233ae3ee     NaN
# 16877  118          20180307   None  b6f74fc8e1664cfb9b44834dd9f7cf48     NaN
# 16885  118          20150804   None  123ec648e228460589182607c0db4dd5     NaN
# 16906  118          20170729   None  09f61d1d6e05402ca923d614dda52d57     NaN
# 16915  118          20171021   None  7b32b3085ad540a58482c091b1dca914     NaN
# 16923  118          20160209   None  54ed2d25754a486fba36eb5c7541203a     NaN
# 16931  118          20170913   None  e6843a4996574eb693ab864ecc406d56     NaN
# 16942  118          20170728   None  ba12d53863b3456f930ac62e2503fe48     NaN
# 16951  118          20171029   None  5ca2620962114246ab218fc648eb3934     NaN
# 16953  118          20170901   None  653d8f383fab43d4a93b10b02bd67266     NaN
# 16969  118          20131212   None  f19d9482309d4e93ad74935f9e46e44c     NaN
# 16977  118          20160609   None  eb7dd979f4644052a5c401a01f129132     NaN
# 16980  118          20160901   None  5c686d09ca4d475a8f750f2ba07e0440     NaN
# 16982  118          20160415   None  d9ca82f550ac4ee58b6299cf1e5c824a     NaN
# 16989  118          20180305   None  ca45ee1883624304bac1e4c8a114f045     NaN
# 16991  118          20160116   None  a9a20fa8b5504360beb4e7c8712f8306     NaN
# 16994  118          20151211   None  c02b10e8752c4d8e9b73f918558531f7     NaN
#
# [2175 rows x 5 columns]

# %% [markdown]
# *All customers of unknwon age (118) have no gender nor income info. Those coulde be removed.*

# %%
profile.age.value_counts().sort_index(ascending=False)
# Out:
# 118    2175
# 101       5
# 100      12
# 99        5
# 98        5
# 97       13
# 96        8
# 95       22
# 94       33
# 93       29
# 92       40
# 91       47
# 90       52
# 89       53
# 88       64
# 87       66
# 86       54
# 85       70
# 84       83
# 83      102
# 82      105
# 81      118
# 80      116
# 79      117
# 78      135
# 77      141
# 76      155
# 75      159
# 74      193
# 73      209
#        ...
# 47      232
# 46      212
# 45      231
# 44      192
# 43      215
# 42      227
# 41      189
# 40      202
# 39      182
# 38      172
# 37      197
# 36      175
# 35      118
# 34      147
# 33      152
# 32      139
# 31      113
# 30      131
# 29      129
# 28      137
# 27      139
# 26      157
# 25      136
# 24      139
# 23      126
# 22      131
# 21      140
# 20      135
# 19      135
# 18       70
# Name: age, Length: 85, dtype: int64

# %% [markdown]
# *Oldest customers are 101 years old. Hmm... Interesting..*

# %% [markdown]
# <a id='transcript_analysis'></a>
# #### C. Transcript.json

# %%
transcript.head()
# Out:
#             event                            person  time  \
# 0  offer received  78afa995795e4d85b5d9ceeca43f5fef     0
# 1  offer received  a03223e636434f42ac4c3df47e8bac43     0
# 2  offer received  e2127556f4f64592b11af22de27a7932     0
# 3  offer received  8ec6ce2a7e7949b1bf142def7d0e0586     0
# 4  offer received  68617ca6246f4fbc85e91a2a49552598     0
#
#                                               value
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}

# %% [markdown]
# *May be this table can be pivoted by person to look like Person, Time of offer received, Time of offer viewed, time of offer completed,offer id,  reward, amount*

# %%
#Just a thought..
person_event = transcript.groupby(['person', 'event'])['time'].max().unstack()
person_event.head()
# Out:
# event                             offer completed  offer received  \
# person
# 0009655768c64bdeb2e877511632db8f            576.0           576.0
# 00116118485d4dfda04fdbaba9a87b5c              NaN           576.0
# 0011e0d4e6b944f998e987f904e8c1e5            576.0           504.0
# 0020c2b971eb4e9188eac86d93036a77            510.0           504.0
# 0020ccbbb6d84e358d3414a3ff76cffd            600.0           504.0
#
# event                             offer viewed  transaction
# person
# 0009655768c64bdeb2e877511632db8f         540.0        696.0
# 00116118485d4dfda04fdbaba9a87b5c         630.0        474.0
# 0011e0d4e6b944f998e987f904e8c1e5         516.0        654.0
# 0020c2b971eb4e9188eac86d93036a77         660.0        708.0
# 0020ccbbb6d84e358d3414a3ff76cffd         582.0        672.0

# %%
person_event.columns
#There is no person column, so can't refer to persons by their ids.
# Out:
# Index(['offer completed', 'offer received', 'offer viewed', 'transaction'], dtype='object', name='event')

# %%
transcript.shape
# Out:
# (306534, 4)

# %%
transcript.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306534 entries, 0 to 306533
# Data columns (total 4 columns):
# event     306534 non-null object
# person    306534 non-null object
# time      306534 non-null int64
# value     306534 non-null object
# dtypes: int64(1), object(3)
# memory usage: 9.4+ MB

# %%
transcript.describe()
# Out:
#                 time
# count  306534.000000
# mean      366.382940
# std       200.326314
# min         0.000000
# 25%       186.000000
# 50%       408.000000
# 75%       528.000000
# max       714.000000

# %%
transcript.hist(figsize= (15,12));  #histogram of whole dataset

# %%
transcript.event.value_counts()
# Out:
# transaction        138953
# offer received      76277
# offer viewed        57725
# offer completed     33579
# Name: event, dtype: int64

# %% [markdown]
# *Percent of completed offers = 33579/76277 x 100 = 44.022%*

# %%
transcript.person.value_counts()
# Out:
# 94de646f7b6041228ca7dec82adb97d2    51
# 8dbfa485249f409aa223a2130f40634a    49
# 79d9d4f86aca4bed9290350fb43817c2    48
# d0a80415b84c4df4908b8403b19765e3    48
# 5e60c6aa3b834e44b822ea43a3efea26    48
# a42ed50acc4d4b25bca647c9e0b916ad    46
# bd2cdd691aca4bb0a0e039979ee5de5c    46
# b1f4ece7d49342628a9ed77aee2cde58    46
# 28681c16026943e68f26feaccab0907f    46
# ab25fd6fbd5040f880751921e4029757    44
# 86e9d338b85b4177b369fe6b0ad4fed3    43
# d087fd0166404163b7d1e1e7cf2a9ac7    43
# 4142f5e23db741b1af4be0287dc91c1c    43
# 9ae56116908640fc83477982da0aaec4    43
# ca265792e65949d79b2b0e91bdd31c57    43
# 0ebc3c4c39234ab6a2701fe2525705a9    42
# cd9bac9e8aea4609929a55b9b468c88e    42
# 8e7d398d4bd948e397e201ad2bd5cce8    42
# 0d74b166a5e54b269795dbaf38c6dfae    42
# 40ce078d5b2a43d19138a788754520be    42
# edc7b04392144da9979f3077095f268a    42
# 1d755c218f714559a57ee7df7e6b1ca0    41
# 417c8e42cba54dd0ba1ea7ee079ef87a    41
# 5da599f0f0ca40a6916e28487a55e655    41
# 81a263ee0b8544b6a8910ee690cc6edd    41
# f0a3a3c05e3c4e2e84929a49a6b5488c    41
# 6cd32ababc644c6c8a2644368c795728    41
# 2ddc7d63c32d4606a7a45e3e70439b44    41
# 562b9efc809b4bd897ce0381347aaea2    41
# a6fce370a2ce4df995fc4899bfeb3b6a    41
#                                     ..
# a1cf230d997a4037b723673d19f00bac     4
# a33e1e7f26ea4b9a824bf1902ee073fc     4
# 11e2d9f6ef474d13bcf1db21f5c7bb62     4
# 76341c0cc6684b3eb23661e195dfc9a3     3
# 50f26d1787444bb6a1e1b8be501f6877     3
# 12ede229379747bd8d74ccdc20097ca3     3
# 2e9660f6e83b49bbb9d533b9317359c4     3
# 08e7c2a166ff44e4a009a18b5e8e4b81     3
# 1b978feee51d4afe83ecde1ae78907cc     3
# 3a4874d8f0ef42b9a1b72294902afea9     3
# f67a6524092d48a788a415c453bd2e00     3
# 19a0510b9ce24b9da44618f7161ae72d     3
# ce1579c557c14f7785869dc80638bc0f     3
# af63cf0ed6ad4c458a03cb321927b463     3
# fafcd6ee168140fbbb5da43be1d3daa7     3
# bc0c484263b94b0896f20c5e4fdf3585     3
# d727102ac242449ab15f1bd1af28e6ff     3
# 83abd8407034461782483fb32d3d5f5c     3
# 912b9f623b9e4b4eb99b6dc919f09a93     2
# fccc9279ba56411f80ffe8ce7e0935cd     2
# 3045af4e98794a04a5542d3eac939b1f     2
# afd41b230f924f9ca8f5ed6249616114     2
# e63e42480aae4ede9f07cac49c8c3f78     2
# 3a4e53046c544134bb1e7782248631d1     2
# cae5e211053f4121a389a7da4d631f7f     2
# 1bfe13d2453c4185a6486c6817e0d568     2
# 22617705eec442e0b7b43e5c5f56fb17     2
# 7ecfc592171f4844bdc05bdbb48d3847     2
# df9fc9a86ca84ef5aedde8925d5838ba     2
# da7a7c0dcfcb41a8acc7864a53cf60fb     1
# Name: person, Length: 17000, dtype: int64

# %%
transcript.value.value_counts()
# Out:
# {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}                  14983
# {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}                  14924
# {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}                  14891
# {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}                  14835
# {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}                  14374
# {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}                  14305
# {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}                  11848
# {'offer id': '3f207df678b143eea3cee63160fa8bed'}                  11761
# {'offer id': '2906b810c7d4411798c6938adc9daaa5'}                  11750
# {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}                  10331
# {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4', 'reward': 2}      5317
# {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2', 'reward': 3}      5156
# {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9', 'reward': 5}      4354
# {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d', 'reward': 5}      4296
# {'offer_id': '2906b810c7d4411798c6938adc9daaa5', 'reward': 2}      4017
# {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd', 'reward': 10}     3688
# {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7', 'reward': 5}      3420
# {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0', 'reward': 10}     3331
# {'amount': 0.05}                                                    431
# {'amount': 0.66}                                                    166
# {'amount': 1.18}                                                    165
# {'amount': 1.01}                                                    163
# {'amount': 1.23}                                                    161
# {'amount': 0.9}                                                     161
# {'amount': 0.53}                                                    159
# {'amount': 0.5}                                                     159
# {'amount': 1.19}                                                    159
# {'amount': 0.79}                                                    157
# {'amount': 1.5}                                                     156
# {'amount': 0.92}                                                    156
#                                                                   ...
# {'amount': 49.73}                                                     1
# {'amount': 749.29}                                                    1
# {'amount': 83.03}                                                     1
# {'amount': 51.06}                                                     1
# {'amount': 53.4}                                                      1
# {'amount': 47.2}                                                      1
# {'amount': 1015.73}                                                   1
# {'amount': 40.83}                                                     1
# {'amount': 54.44}                                                     1
# {'amount': 39.82}                                                     1
# {'amount': 456.79}                                                    1
# {'amount': 49.82}                                                     1
# {'amount': 41.61}                                                     1
# {'amount': 619.63}                                                    1
# {'amount': 50.37}                                                     1
# {'amount': 45.76}                                                     1
# {'amount': 36.99}                                                     1
# {'amount': 773.21}                                                    1
# {'amount': 577.21}                                                    1
# {'amount': 37.3}                                                      1
# {'amount': 792.54}                                                    1
# {'amount': 49.38}                                                     1
# {'amount': 769.04}                                                    1
# {'amount': 384.03}                                                    1
# {'amount': 493.4}                                                     1
# {'amount': 439.14}                                                    1
# {'amount': 42.75}                                                     1
# {'amount': 650.75}                                                    1
# {'amount': 943.4}                                                     1
# {'amount': 44.21}                                                     1
# Name: value, Length: 5121, dtype: int64

# %% [markdown]
# *Offer id sometimes written as offer_id. This needs standardization*

# %% [markdown]
# <a id='methodology'></a>
# ## 5. Methodology
# <a id='preprocessing'></a>
# ### A. Data Preprocessing

# %%
# Change 'offer id' to 'offer_id' in value column

transcript_value_list = []

for value in transcript.value.values:
    # Keys are hashable which usually implies they're immutable and can't be modified. So, we create a new key-value pair equals
    # the one we want to rename (with correct name) and delete the wrong one.
    if 'offer id' in value.keys():
        value['offer_id'] = value['offer id']
        del value['offer id']
    transcript_value_list.append(value)

transcript_value_list
# Out:
# [{'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'},
#  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'},
#  {'offer_id': '3f207df678b143eea3cee63160fa8bed'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'},
#  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'},
#  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'},
#  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'},
#  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'},
#  ...]

# %%
# Create dataframe from transcript_value_list
transcript_value = pd.DataFrame(transcript_value_list, columns = ['offer_id', 'reward', 'amount'])
transcript_value.head()
# Out:
#                            offer_id  reward  amount
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 2  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 3  fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN

# %%
transcript_value.info()
# offer_id values increased to 167581 instead of 134002 after changing 'offer id' to 'offer_id'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306534 entries, 0 to 306533
# Data columns (total 3 columns):
# offer_id    167581 non-null object
# reward      33579 non-null float64
# amount      138953 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 7.0+ MB

# %%
# Merge transcript & new_transcript datasets using index.
new_transcript = pd.merge(transcript, transcript_value, left_index=True, right_index=True)
new_transcript.head()
# Out:
#             event                            person  time  \
# 0  offer received  78afa995795e4d85b5d9ceeca43f5fef     0
# 1  offer received  a03223e636434f42ac4c3df47e8bac43     0
# 2  offer received  e2127556f4f64592b11af22de27a7932     0
# 3  offer received  8ec6ce2a7e7949b1bf142def7d0e0586     0
# 4  offer received  68617ca6246f4fbc85e91a2a49552598     0
#
#                                               value  \
# 0  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 1  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 2  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'}
# 3  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 4  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}
#
#                            offer_id  reward  amount
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 2  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 3  fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN

# %%
new_transcript.sample(20)
# Out:
#                  event                            person  time  \
# 270018    offer viewed  98da26ac30d94be693bc1c0050b73aae   594
# 72213     offer viewed  06b99e8cc24b426f8a578c749974b88a   180
# 215313     transaction  6c2c85ad5b244122a70425e6be34e0fd   504
# 165876     transaction  baed4fb2389046e3bfa57253b3d6d6bb   408
# 76236     offer viewed  04aa84f9a46a4920b70386c3fe60165d   186
# 118517  offer received  1c0392ee64b3495abdebc3d6002f027c   336
# 54229   offer received  f7c9157f08384ff29f1d11e9388ed4c2   168
# 147922    offer viewed  277d5c3110104e278963d796465f45a8   396
# 256135  offer received  8f5146270f5745d4862514da8a7b6620   576
# 169055    offer viewed  1981c9ebfc3c4e1fa532035806a8c60e   414
# 204284  offer received  8140d90b53c54b0687ddd58ee64bd9d6   504
# 288115     transaction  9a674564f21d4478bed54a86b25fceb0   642
# 23861     offer viewed  dc7d0fdb90ef40639fa327c45e01c01e    24
# 53618   offer received  af44c9f11887442aabb07c86e31be442   168
# 242095     transaction  2592eba5061344858194f091dea0af7b   564
# 123037  offer received  7f09dd8ae6994415ada38d63383cf086   336
# 197133     transaction  c095dad5bf3a452389143ab4b864f10b   486
# 8369    offer received  5d2b8131ed9847c4b6606c534aef7ceb     0
# 11865   offer received  84b312074efd4a458cc21cd32dae7454     0
# 25254     offer viewed  bbef9db2011e494ba7df025a9817f44d    30
#
#                                                    value  \
# 270018  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 72213   {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'}
# 215313                                  {'amount': 6.46}
# 165876                                  {'amount': 1.51}
# 76236   {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 118517  {'offer_id': '5a8bc65990b245e5a138643cd4eb9837'}
# 54229   {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 147922  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 256135  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}
# 169055  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d'}
# 204284  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}
# 288115                                  {'amount': 2.48}
# 23861   {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 53618   {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 242095                                  {'amount': 4.82}
# 123037  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 197133                                  {'amount': 0.26}
# 8369    {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 11865   {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 25254   {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
#
#                                 offer_id  reward  amount
# 270018  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 72213   5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 215313                               NaN     NaN    6.46
# 165876                               NaN     NaN    1.51
# 76236   0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 118517  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 54229   2298d6c36e964ae4a3e7e9706d1fb8c2     NaN     NaN
# 147922  ae264e3637204a6fb9bb56bc8210ddfd     NaN     NaN
# 256135  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN
# 169055  f19421c1d4aa40978ebb69ca19b0e20d     NaN     NaN
# 204284  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN
# 288115                               NaN     NaN    2.48
# 23861   9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 53618   ae264e3637204a6fb9bb56bc8210ddfd     NaN     NaN
# 242095                               NaN     NaN    4.82
# 123037  ae264e3637204a6fb9bb56bc8210ddfd     NaN     NaN
# 197133                               NaN     NaN    0.26
# 8369    ae264e3637204a6fb9bb56bc8210ddfd     NaN     NaN
# 11865   fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 25254   2298d6c36e964ae4a3e7e9706d1fb8c2     NaN     NaN

# %%
# Merge profile & new_transcript datasets using id in profile and person in new_transcript.
profile_new_transcript = pd.merge(profile, new_transcript, left_on='id', right_on = 'person', how='left' )
profile_new_transcript.head()
# Out:
#    age  became_member_on gender                                id  income  \
# 0  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783     NaN
# 1  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783     NaN
# 2  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783     NaN
# 3  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783     NaN
# 4  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783     NaN
#
#             event                            person  time  \
# 0  offer received  68be06ca386d4c31939f3a4f0e3dd783   168
# 1    offer viewed  68be06ca386d4c31939f3a4f0e3dd783   216
# 2  offer received  68be06ca386d4c31939f3a4f0e3dd783   336
# 3    offer viewed  68be06ca386d4c31939f3a4f0e3dd783   348
# 4     transaction  68be06ca386d4c31939f3a4f0e3dd783   360
#
#                                               value  \
# 0  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'}
# 1  {'offer_id': '2906b810c7d4411798c6938adc9daaa5'}
# 2  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 3  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 4                   {'amount': 0.35000000000000003}
#
#                            offer_id  reward  amount
# 0  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 1  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 2  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 3  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 4                               NaN     NaN    0.35

# %%
profile_new_transcript.shape
# Out:
# (306534, 12)

# %%
transcript.loc[(transcript.person == '68be06ca386d4c31939f3a4f0e3dd783'), 'value']
# Out:
# 53174      {'offer_id': '2906b810c7d4411798c6938adc9daaa5'}
# 85290      {'offer_id': '2906b810c7d4411798c6938adc9daaa5'}
# 110828     {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 130147     {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 135224                      {'amount': 0.35000000000000003}
# 150596     {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 163374     {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 167626                                     {'amount': 0.74}
# 182544                       {'amount': 1.8900000000000001}
# 201570     {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 214274     {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}
# 218392                                     {'amount': 5.04}
# 230411                                     {'amount': 0.38}
# 237364                                     {'amount': 2.12}
# 237365    {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...
# 237366    {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...
# 245122     {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 262137     {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 274519                                     {'amount': 4.61}
# 283959                                     {'amount': 0.06}
# 301915                                     {'amount': 5.21}
# Name: value, dtype: object

# %%
transcript.loc[(transcript.person == '68be06ca386d4c31939f3a4f0e3dd783'), 'event']
# Out:
# 53174      offer received
# 85290        offer viewed
# 110828     offer received
# 130147       offer viewed
# 135224        transaction
# 150596     offer received
# 163374       offer viewed
# 167626        transaction
# 182544        transaction
# 201570     offer received
# 214274       offer viewed
# 218392        transaction
# 230411        transaction
# 237364        transaction
# 237365    offer completed
# 237366    offer completed
# 245122     offer received
# 262137       offer viewed
# 274519        transaction
# 283959        transaction
# 301915        transaction
# Name: event, dtype: object

# %%
#Drop rows with no demographic values as they will not give us any insights after analysis even if they have made purchases.
no_nan = profile_new_transcript.dropna(subset=['gender'])
no_nan.head()
# Out:
#     age  became_member_on gender                                id    income  \
# 21   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 22   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 23   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 24   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 25   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
#
#              event                            person  time  \
# 21     transaction  0610b486422d4921ae7d2bf64640c50b    18
# 22     transaction  0610b486422d4921ae7d2bf64640c50b   144
# 23  offer received  0610b486422d4921ae7d2bf64640c50b   408
# 24  offer received  0610b486422d4921ae7d2bf64640c50b   504
# 25     transaction  0610b486422d4921ae7d2bf64640c50b   528
#
#                                                value  \
# 21                                 {'amount': 21.51}
# 22                                 {'amount': 32.28}
# 23  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 24  {'offer_id': '3f207df678b143eea3cee63160fa8bed'}
# 25                                 {'amount': 23.22}
#
#                             offer_id  reward  amount
# 21                               NaN     NaN   21.51
# 22                               NaN     NaN   32.28
# 23  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 24  3f207df678b143eea3cee63160fa8bed     NaN     NaN
# 25                               NaN     NaN   23.22

# %%
# Merge no_nan & portfolio datasets using offer_id in id and person in portfolio.
new_df = pd.merge(no_nan, portfolio, left_on='offer_id', right_on = 'id', how='left' )
new_df.head()
# Need to rename reward_x & reward_y
# Out:
#    age  became_member_on gender                              id_x    income  \
# 0   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 1   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 2   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 3   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 4   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
#
#             event                            person  time  \
# 0     transaction  0610b486422d4921ae7d2bf64640c50b    18
# 1     transaction  0610b486422d4921ae7d2bf64640c50b   144
# 2  offer received  0610b486422d4921ae7d2bf64640c50b   408
# 3  offer received  0610b486422d4921ae7d2bf64640c50b   504
# 4     transaction  0610b486422d4921ae7d2bf64640c50b   528
#
#                                               value  \
# 0                                 {'amount': 21.51}
# 1                                 {'amount': 32.28}
# 2  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 3  {'offer_id': '3f207df678b143eea3cee63160fa8bed'}
# 4                                 {'amount': 23.22}
#
#                            offer_id  reward_x  amount              channels  \
# 0                               NaN       NaN   21.51                   NaN
# 1                               NaN       NaN   32.28                   NaN
# 2  9b98b8c7a33c4b65b9aebfe6a799e6d9       NaN     NaN  [web, email, mobile]
# 3  3f207df678b143eea3cee63160fa8bed       NaN     NaN  [web, email, mobile]
# 4                               NaN       NaN   23.22                   NaN
#
#    difficulty  duration                              id_y     offer_type  \
# 0         NaN       NaN                               NaN            NaN
# 1         NaN       NaN                               NaN            NaN
# 2         5.0       7.0  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo
# 3         0.0       4.0  3f207df678b143eea3cee63160fa8bed  informational
# 4         NaN       NaN                               NaN            NaN
#
#    reward_y
# 0       NaN
# 1       NaN
# 2       5.0
# 3       0.0
# 4       NaN

# %%
# Drop person's id (id_x) since it's no longer needed as "person" column replaced it.
# Drop value since it's been extracted into separate columns.
# Drop id_y since it's the same as offer id.
final_df = new_df.drop(columns=['id_x', 'value', 'id_y'])
# Rename columns
final_df = final_df.rename(columns = {'reward_x':'earned_reward', 'reward_y': 'offer_reward',
                                      'time':'event_time', 'duration': 'offer_duration'})
final_df.head(10)
# Out:
#    age  became_member_on gender    income            event  \
# 0   55          20170715      F  112000.0      transaction
# 1   55          20170715      F  112000.0      transaction
# 2   55          20170715      F  112000.0   offer received
# 3   55          20170715      F  112000.0   offer received
# 4   55          20170715      F  112000.0      transaction
# 5   55          20170715      F  112000.0  offer completed
# 6   75          20170509      F  100000.0   offer received
# 7   75          20170509      F  100000.0     offer viewed
# 8   75          20170509      F  100000.0      transaction
# 9   75          20170509      F  100000.0  offer completed
#
#                              person  event_time  \
# 0  0610b486422d4921ae7d2bf64640c50b          18
# 1  0610b486422d4921ae7d2bf64640c50b         144
# 2  0610b486422d4921ae7d2bf64640c50b         408
# 3  0610b486422d4921ae7d2bf64640c50b         504
# 4  0610b486422d4921ae7d2bf64640c50b         528
# 5  0610b486422d4921ae7d2bf64640c50b         528
# 6  78afa995795e4d85b5d9ceeca43f5fef           0
# 7  78afa995795e4d85b5d9ceeca43f5fef           6
# 8  78afa995795e4d85b5d9ceeca43f5fef         132
# 9  78afa995795e4d85b5d9ceeca43f5fef         132
#
#                            offer_id  earned_reward  amount  \
# 0                               NaN            NaN   21.51
# 1                               NaN            NaN   32.28
# 2  9b98b8c7a33c4b65b9aebfe6a799e6d9            NaN     NaN
# 3  3f207df678b143eea3cee63160fa8bed            NaN     NaN
# 4                               NaN            NaN   23.22
# 5  9b98b8c7a33c4b65b9aebfe6a799e6d9            5.0     NaN
# 6  9b98b8c7a33c4b65b9aebfe6a799e6d9            NaN     NaN
# 7  9b98b8c7a33c4b65b9aebfe6a799e6d9            NaN     NaN
# 8                               NaN            NaN   19.89
# 9  9b98b8c7a33c4b65b9aebfe6a799e6d9            5.0     NaN
#
#                channels  difficulty  offer_duration     offer_type  \
# 0                   NaN         NaN             NaN            NaN
# 1                   NaN         NaN             NaN            NaN
# 2  [web, email, mobile]         5.0             7.0           bogo
# 3  [web, email, mobile]         0.0             4.0  informational
# 4                   NaN         NaN             NaN            NaN
# 5  [web, email, mobile]         5.0             7.0           bogo
# 6  [web, email, mobile]         5.0             7.0           bogo
# 7  [web, email, mobile]         5.0             7.0           bogo
# 8                   NaN         NaN             NaN            NaN
# 9  [web, email, mobile]         5.0             7.0           bogo
#
#    offer_reward
# 0           NaN
# 1           NaN
# 2           5.0
# 3           0.0
# 4           NaN
# 5           5.0
# 6           5.0
# 7           5.0
# 8           NaN
# 9           5.0

# %%
# Rename columns
final_df = final_df.rename(columns = {'reward_x':'earned_reward', 'reward_y': 'offer_reward',
                                      'time':'event_time', 'duration': 'offer_duration'})
final_df.head()
# Out:
#    age  became_member_on gender    income           event  \
# 0   55          20170715      F  112000.0     transaction
# 1   55          20170715      F  112000.0     transaction
# 2   55          20170715      F  112000.0  offer received
# 3   55          20170715      F  112000.0  offer received
# 4   55          20170715      F  112000.0     transaction
#
#                              person  event_time  \
# 0  0610b486422d4921ae7d2bf64640c50b          18
# 1  0610b486422d4921ae7d2bf64640c50b         144
# 2  0610b486422d4921ae7d2bf64640c50b         408
# 3  0610b486422d4921ae7d2bf64640c50b         504
# 4  0610b486422d4921ae7d2bf64640c50b         528
#
#                            offer_id  earned_reward  amount  \
# 0                               NaN            NaN   21.51
# 1                               NaN            NaN   32.28
# 2  9b98b8c7a33c4b65b9aebfe6a799e6d9            NaN     NaN
# 3  3f207df678b143eea3cee63160fa8bed            NaN     NaN
# 4                               NaN            NaN   23.22
#
#                channels  difficulty  offer_duration     offer_type  \
# 0                   NaN         NaN             NaN            NaN
# 1                   NaN         NaN             NaN            NaN
# 2  [web, email, mobile]         5.0             7.0           bogo
# 3  [web, email, mobile]         0.0             4.0  informational
# 4                   NaN         NaN             NaN            NaN
#
#    offer_reward
# 0           NaN
# 1           NaN
# 2           5.0
# 3           0.0
# 4           NaN

# %%
# Re-arrange columns
final_df = final_df[['person', 'age', 'gender', 'income','became_member_on', 'event', 'event_time', 'offer_type',
                     'offer_reward', 'earned_reward', 'amount','offer_id', 'channels', 'difficulty', 'offer_duration']]
final_df.head(10)
# Out:
#                              person  age gender    income  became_member_on  \
# 0  0610b486422d4921ae7d2bf64640c50b   55      F  112000.0          20170715
# 1  0610b486422d4921ae7d2bf64640c50b   55      F  112000.0          20170715
# 2  0610b486422d4921ae7d2bf64640c50b   55      F  112000.0          20170715
# 3  0610b486422d4921ae7d2bf64640c50b   55      F  112000.0          20170715
# 4  0610b486422d4921ae7d2bf64640c50b   55      F  112000.0          20170715
# 5  0610b486422d4921ae7d2bf64640c50b   55      F  112000.0          20170715
# 6  78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0          20170509
# 7  78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0          20170509
# 8  78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0          20170509
# 9  78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0          20170509
#
#              event  event_time     offer_type  offer_reward  earned_reward  \
# 0      transaction          18            NaN           NaN            NaN
# 1      transaction         144            NaN           NaN            NaN
# 2   offer received         408           bogo           5.0            NaN
# 3   offer received         504  informational           0.0            NaN
# 4      transaction         528            NaN           NaN            NaN
# 5  offer completed         528           bogo           5.0            5.0
# 6   offer received           0           bogo           5.0            NaN
# 7     offer viewed           6           bogo           5.0            NaN
# 8      transaction         132            NaN           NaN            NaN
# 9  offer completed         132           bogo           5.0            5.0
#
#    amount                          offer_id              channels  difficulty  \
# 0   21.51                               NaN                   NaN         NaN
# 1   32.28                               NaN                   NaN         NaN
# 2     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9  [web, email, mobile]         5.0
# 3     NaN  3f207df678b143eea3cee63160fa8bed  [web, email, mobile]         0.0
# 4   23.22                               NaN                   NaN         NaN
# 5     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9  [web, email, mobile]         5.0
# 6     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9  [web, email, mobile]         5.0
# 7     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9  [web, email, mobile]         5.0
# 8   19.89                               NaN                   NaN         NaN
# 9     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9  [web, email, mobile]         5.0
#
#    offer_duration
# 0             NaN
# 1             NaN
# 2             7.0
# 3             4.0
# 4             NaN
# 5             7.0
# 6             7.0
# 7             7.0
# 8             NaN
# 9             7.0

# %%
final_df_by_person = final_df.groupby('person')
final_df_by_person.head()
# Useless. Missing rows (ex: row 5)
# Out:
#                                   person  age gender    income  \
# 0       0610b486422d4921ae7d2bf64640c50b   55      F  112000.0
# 1       0610b486422d4921ae7d2bf64640c50b   55      F  112000.0
# 2       0610b486422d4921ae7d2bf64640c50b   55      F  112000.0
# 3       0610b486422d4921ae7d2bf64640c50b   55      F  112000.0
# 4       0610b486422d4921ae7d2bf64640c50b   55      F  112000.0
# 6       78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 7       78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 8       78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 9       78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 10      78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 24      e2127556f4f64592b11af22de27a7932   68      M   70000.0
# 25      e2127556f4f64592b11af22de27a7932   68      M   70000.0
# 26      e2127556f4f64592b11af22de27a7932   68      M   70000.0
# 27      e2127556f4f64592b11af22de27a7932   68      M   70000.0
# 28      e2127556f4f64592b11af22de27a7932   68      M   70000.0
# 36      389bc3fa690240e798340f5a15918d5c   65      M   53000.0
# 37      389bc3fa690240e798340f5a15918d5c   65      M   53000.0
# 38      389bc3fa690240e798340f5a15918d5c   65      M   53000.0
# 39      389bc3fa690240e798340f5a15918d5c   65      M   53000.0
# 40      389bc3fa690240e798340f5a15918d5c   65      M   53000.0
# 56      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 57      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 58      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 59      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 60      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 66      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 67      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 68      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 69      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 70      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# ...                                  ...  ...    ...       ...
# 272679  cb23b66c56f64b109d673d5e56574529   60      M  113000.0
# 272680  cb23b66c56f64b109d673d5e56574529   60      M  113000.0
# 272681  cb23b66c56f64b109d673d5e56574529   60      M  113000.0
# 272682  cb23b66c56f64b109d673d5e56574529   60      M  113000.0
# 272683  cb23b66c56f64b109d673d5e56574529   60      M  113000.0
# 272688  6d5f3a774f3d4714ab0c092238f3a1d7   45      F   54000.0
# 272689  6d5f3a774f3d4714ab0c092238f3a1d7   45      F   54000.0
# 272690  6d5f3a774f3d4714ab0c092238f3a1d7   45      F   54000.0
# 272691  6d5f3a774f3d4714ab0c092238f3a1d7   45      F   54000.0
# 272692  6d5f3a774f3d4714ab0c092238f3a1d7   45      F   54000.0
# 272701  2cb4f97358b841b9a9773a7aa05a9d77   61      M   72000.0
# 272702  2cb4f97358b841b9a9773a7aa05a9d77   61      M   72000.0
# 272703  2cb4f97358b841b9a9773a7aa05a9d77   61      M   72000.0
# 272704  2cb4f97358b841b9a9773a7aa05a9d77   61      M   72000.0
# 272705  2cb4f97358b841b9a9773a7aa05a9d77   61      M   72000.0
# 272713  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272714  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272715  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272716  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272717  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272725  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272726  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272727  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272728  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272729  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272748  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272749  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272750  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272751  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272752  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
#
#         became_member_on            event  event_time     offer_type  \
# 0               20170715      transaction          18            NaN
# 1               20170715      transaction         144            NaN
# 2               20170715   offer received         408           bogo
# 3               20170715   offer received         504  informational
# 4               20170715      transaction         528            NaN
# 6               20170509   offer received           0           bogo
# 7               20170509     offer viewed           6           bogo
# 8               20170509      transaction         132            NaN
# 9               20170509  offer completed         132           bogo
# 10              20170509      transaction         144            NaN
# 24              20180426   offer received           0       discount
# 25              20180426     offer viewed          18       discount
# 26              20180426      transaction         288            NaN
# 27              20180426      transaction         294            NaN
# 28              20180426   offer received         336  informational
# 36              20180209   offer received           0           bogo
# 37              20180209     offer viewed           0           bogo
# 38              20180209      transaction          60            NaN
# 39              20180209  offer completed          60           bogo
# 40              20180209   offer received         168           bogo
# 56              20171111   offer received           0  informational
# 57              20171111   offer received         168       discount
# 58              20171111     offer viewed         168       discount
# 59              20171111      transaction         216            NaN
# 60              20171111   offer received         336       discount
# 66              20170911   offer received           0       discount
# 67              20170911     offer viewed          18       discount
# 68              20170911   offer received         168           bogo
# 69              20170911     offer viewed         168           bogo
# 70              20170911      transaction         210            NaN
# ...                  ...              ...         ...            ...
# 272679          20180505   offer received           0       discount
# 272680          20180505      transaction         156            NaN
# 272681          20180505  offer completed         156       discount
# 272682          20180505      transaction         186            NaN
# 272683          20180505      transaction         222            NaN
# 272688          20180604      transaction          60            NaN
# 272689          20180604      transaction          84            NaN
# 272690          20180604      transaction         192            NaN
# 272691          20180604      transaction         246            NaN
# 272692          20180604      transaction         324            NaN
# 272701          20180713   offer received           0  informational
# 272702          20180713     offer viewed          42  informational
# 272703          20180713      transaction         126            NaN
# 272704          20180713      transaction         270            NaN
# 272705          20180713      transaction         276            NaN
# 272713          20170126   offer received           0       discount
# 272714          20170126   offer received         168  informational
# 272715          20170126      transaction         204            NaN
# 272716          20170126   offer received         336  informational
# 272717          20170126      transaction         372            NaN
# 272725          20160307      transaction          24            NaN
# 272726          20160307      transaction         150            NaN
# 272727          20160307      transaction         228            NaN
# 272728          20160307   offer received         336           bogo
# 272729          20160307     offer viewed         342           bogo
# 272748          20170722   offer received           0       discount
# 272749          20170722     offer viewed           6       discount
# 272750          20170722      transaction          54            NaN
# 272751          20170722  offer completed          54       discount
# 272752          20170722      transaction          84            NaN
#
#         offer_reward  earned_reward  amount                          offer_id  \
# 0                NaN            NaN   21.51                               NaN
# 1                NaN            NaN   32.28                               NaN
# 2                5.0            NaN     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 3                0.0            NaN     NaN  3f207df678b143eea3cee63160fa8bed
# 4                NaN            NaN   23.22                               NaN
# 6                5.0            NaN     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 7                5.0            NaN     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 8                NaN            NaN   19.89                               NaN
# 9                5.0            5.0     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 10               NaN            NaN   17.78                               NaN
# 24               2.0            NaN     NaN  2906b810c7d4411798c6938adc9daaa5
# 25               2.0            NaN     NaN  2906b810c7d4411798c6938adc9daaa5
# 26               NaN            NaN   17.88                               NaN
# 27               NaN            NaN   21.43                               NaN
# 28               0.0            NaN     NaN  3f207df678b143eea3cee63160fa8bed
# 36               5.0            NaN     NaN  f19421c1d4aa40978ebb69ca19b0e20d
# 37               5.0            NaN     NaN  f19421c1d4aa40978ebb69ca19b0e20d
# 38               NaN            NaN    9.54                               NaN
# 39               5.0            5.0     NaN  f19421c1d4aa40978ebb69ca19b0e20d
# 40               5.0            NaN     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 56               0.0            NaN     NaN  3f207df678b143eea3cee63160fa8bed
# 57               3.0            NaN     NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 58               3.0            NaN     NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 59               NaN            NaN    2.32                               NaN
# 60               2.0            NaN     NaN  fafdcd668e3743c1bb461111dcafc2a4
# 66               5.0            NaN     NaN  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 67               5.0            NaN     NaN  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 68              10.0            NaN     NaN  4d5c57ea9a6940dd891ad53e9dbe8da0
# 69              10.0            NaN     NaN  4d5c57ea9a6940dd891ad53e9dbe8da0
# 70               NaN            NaN   12.33                               NaN
# ...              ...            ...     ...                               ...
# 272679           2.0            NaN     NaN  2906b810c7d4411798c6938adc9daaa5
# 272680           NaN            NaN   21.62                               NaN
# 272681           2.0            2.0     NaN  2906b810c7d4411798c6938adc9daaa5
# 272682           NaN            NaN   27.15                               NaN
# 272683           NaN            NaN   25.94                               NaN
# 272688           NaN            NaN    3.92                               NaN
# 272689           NaN            NaN    2.67                               NaN
# 272690           NaN            NaN    2.97                               NaN
# 272691           NaN            NaN    1.18                               NaN
# 272692           NaN            NaN    2.53                               NaN
# 272701           0.0            NaN     NaN  5a8bc65990b245e5a138643cd4eb9837
# 272702           0.0            NaN     NaN  5a8bc65990b245e5a138643cd4eb9837
# 272703           NaN            NaN    2.93                               NaN
# 272704           NaN            NaN    3.93                               NaN
# 272705           NaN            NaN    2.24                               NaN
# 272713           5.0            NaN     NaN  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 272714           0.0            NaN     NaN  3f207df678b143eea3cee63160fa8bed
# 272715           NaN            NaN    3.30                               NaN
# 272716           0.0            NaN     NaN  5a8bc65990b245e5a138643cd4eb9837
# 272717           NaN            NaN    7.58                               NaN
# 272725           NaN            NaN    6.49                               NaN
# 272726           NaN            NaN   11.51                               NaN
# 272727           NaN            NaN    6.81                               NaN
# 272728          10.0            NaN     NaN  4d5c57ea9a6940dd891ad53e9dbe8da0
# 272729          10.0            NaN     NaN  4d5c57ea9a6940dd891ad53e9dbe8da0
# 272748           3.0            NaN     NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 272749           3.0            NaN     NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 272750           NaN            NaN   21.55                               NaN
# 272751           3.0            3.0     NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 272752           NaN            NaN   25.19                               NaN
#
#                             channels  difficulty  offer_duration
# 0                                NaN         NaN             NaN
# 1                                NaN         NaN             NaN
# 2               [web, email, mobile]         5.0             7.0
# 3               [web, email, mobile]         0.0             4.0
# 4                                NaN         NaN             NaN
# 6               [web, email, mobile]         5.0             7.0
# 7               [web, email, mobile]         5.0             7.0
# 8                                NaN         NaN             NaN
# 9               [web, email, mobile]         5.0             7.0
# 10                               NaN         NaN             NaN
# 24              [web, email, mobile]        10.0             7.0
# 25              [web, email, mobile]        10.0             7.0
# 26                               NaN         NaN             NaN
# 27                               NaN         NaN             NaN
# 28              [web, email, mobile]         0.0             4.0
# 36      [web, email, mobile, social]         5.0             5.0
# 37      [web, email, mobile, social]         5.0             5.0
# 38                               NaN         NaN             NaN
# 39      [web, email, mobile, social]         5.0             5.0
# 40              [web, email, mobile]         5.0             7.0
# 56              [web, email, mobile]         0.0             4.0
# 57      [web, email, mobile, social]         7.0             7.0
# 58      [web, email, mobile, social]         7.0             7.0
# 59                               NaN         NaN             NaN
# 60      [web, email, mobile, social]        10.0            10.0
# 66                      [web, email]        20.0            10.0
# 67                      [web, email]        20.0            10.0
# 68      [web, email, mobile, social]        10.0             5.0
# 69      [web, email, mobile, social]        10.0             5.0
# 70                               NaN         NaN             NaN
# ...                              ...         ...             ...
# 272679          [web, email, mobile]        10.0             7.0
# 272680                           NaN         NaN             NaN
# 272681          [web, email, mobile]        10.0             7.0
# 272682                           NaN         NaN             NaN
# 272683                           NaN         NaN             NaN
# 272688                           NaN         NaN             NaN
# 272689                           NaN         NaN             NaN
# 272690                           NaN         NaN             NaN
# 272691                           NaN         NaN             NaN
# 272692                           NaN         NaN             NaN
# 272701       [email, mobile, social]         0.0             3.0
# 272702       [email, mobile, social]         0.0             3.0
# 272703                           NaN         NaN             NaN
# 272704                           NaN         NaN             NaN
# 272705                           NaN         NaN             NaN
# 272713                  [web, email]        20.0            10.0
# 272714          [web, email, mobile]         0.0             4.0
# 272715                           NaN         NaN             NaN
# 272716       [email, mobile, social]         0.0             3.0
# 272717                           NaN         NaN             NaN
# 272725                           NaN         NaN             NaN
# 272726                           NaN         NaN             NaN
# 272727                           NaN         NaN             NaN
# 272728  [web, email, mobile, social]        10.0             5.0
# 272729  [web, email, mobile, social]        10.0             5.0
# 272748  [web, email, mobile, social]         7.0             7.0
# 272749  [web, email, mobile, social]         7.0             7.0
# 272750                           NaN         NaN             NaN
# 272751  [web, email, mobile, social]         7.0             7.0
# 272752                           NaN         NaN             NaN
#
# [74039 rows x 15 columns]

# %%
final_df.shape
# Out:
# (272762, 15)

# %%
final_df.describe()
# Out:
#                  age         income  became_member_on     event_time  \
# count  272762.000000  272762.000000      2.727620e+05  272762.000000
# mean       53.840696   64337.000755      2.016526e+07     366.707694
# std        17.551337   21243.762941      1.209695e+04     200.359087
# min        18.000000   30000.000000      2.013073e+07       0.000000
# 25%        41.000000   48000.000000      2.016032e+07     186.000000
# 50%        55.000000   62000.000000      2.017041e+07     408.000000
# 75%        66.000000   78000.000000      2.017113e+07     528.000000
# max       101.000000  120000.000000      2.018073e+07     714.000000
#
#         offer_reward  earned_reward         amount     difficulty  \
# count  148805.000000   32444.000000  123957.000000  148805.000000
# mean        4.442445       4.948249      13.996325       7.890561
# std         3.372362       2.905376      31.749420       5.041335
# min         0.000000       2.000000       0.050000       0.000000
# 25%         2.000000       2.000000       3.660000       5.000000
# 50%         5.000000       5.000000      10.800000      10.000000
# 75%         5.000000       5.000000      19.130000      10.000000
# max        10.000000      10.000000    1062.280000      20.000000
#
#        offer_duration
# count   148805.000000
# mean         6.625207
# std          2.133035
# min          3.000000
# 25%          5.000000
# 50%          7.000000
# 75%          7.000000
# max         10.000000

# %% [markdown]
# <a id='storing'></a>
# ### B. Storing Data

# %%
final_df.to_csv('final_df.csv')

# %% [markdown]
# <a id='implementation'></a>
# ### C. Implementation

# %%
# Amount spent by gender
amount_by_gender = dict(final_df.groupby('gender')['amount'].sum())
amount_by_gender
# Out:
# {'F': 863695.00000001106, 'M': 844890.85999999952, 'O': 26356.540000000001}

# %%
plt.figure(figsize=[14.70, 8.27])
base_color = sb.color_palette()[0]
plt.bar(amount_by_gender.keys(), amount_by_gender.values())
plt.title('Amount Spent by Gender', y=1.05, fontsize=14, fontweight='bold')
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('amount Spent', fontweight='bold');

# %% [markdown]
# *Females spend the most, but are very close to males*

# %%
# Amount spent by age
amount_by_age = dict(final_df.groupby("age")["amount"].sum())
amount_by_age
# Out:
# {18: 5632.5700000000061,
#  19: 9705.1199999999826,
#  20: 10379.900000000014,
#  21: 13838.490000000003,
#  22: 12337.020000000015,
#  23: 9818.480000000005,
#  24: 11760.800000000016,
#  25: 11936.839999999997,
#  26: 12718.039999999975,
#  27: 10273.130000000012,
#  28: 12160.999999999989,
#  29: 11758.429999999989,
#  30: 12645.009999999987,
#  31: 8007.0300000000061,
#  32: 13691.470000000036,
#  33: 11796.550000000001,
#  34: 12483.420000000006,
#  35: 12779.549999999999,
#  36: 16143.910000000009,
#  37: 23085.480000000003,
#  38: 20618.240000000027,
#  39: 23116.300000000036,
#  40: 20782.109999999964,
#  41: 21947.259999999998,
#  42: 22937.270000000015,
#  43: 22522.100000000006,
#  44: 22458.149999999961,
#  45: 22820.909999999993,
#  46: 22785.740000000027,
#  47: 21914.619999999974,
#  48: 33091.179999999971,
#  49: 36175.860000000008,
#  50: 36555.160000000054,
#  51: 42257.65999999996,
#  52: 40287.18,
#  53: 50985.189999999981,
#  54: 43417.099999999962,
#  55: 49928.619999999981,
#  56: 40542.100000000049,
#  57: 48138.620000000039,
#  58: 56201.030000000042,
#  59: 43947.54999999993,
#  60: 40548.71000000013,
#  61: 37665.539999999964,
#  62: 41142.340000000047,
#  63: 41243.359999999957,
#  64: 39867.970000000139,
#  65: 37843.279999999941,
#  66: 34884.600000000042,
#  67: 42483.990000000005,
#  68: 33330.199999999946,
#  69: 29689.239999999951,
#  70: 28177.300000000014,
#  71: 29335.829999999976,
#  72: 22648.399999999961,
#  73: 26720.399999999925,
#  74: 25896.040000000001,
#  75: 21424.78000000005,
#  76: 18150.100000000009,
#  77: 18725.270000000011,
#  78: 17089.229999999989,
#  79: 14667.260000000013,
#  80: 15850.119999999979,
#  81: 17076.850000000006,
#  82: 15022.530000000013,
#  83: 14240.049999999999,
#  84: 12257.629999999974,
#  85: 8081.4500000000035,
#  86: 6476.1300000000028,
#  87: 7616.9899999999998,
#  88: 8986.6600000000017,
#  89: 6720.7800000000025,
#  90: 6214.3999999999996,
#  91: 5143.3100000000022,
#  92: 5479.6199999999981,
#  93: 3350.4299999999971,
#  94: 4823.0599999999995,
#  95: 2422.6699999999996,
#  96: 1020.8199999999999,
#  97: 2119.9400000000001,
#  98: 370.38,
#  99: 841.88000000000011,
#  100: 2032.74,
#  101: 877.93000000000006}

# %%
plt.figure(figsize=[14.70, 8.27])
plt.bar(amount_by_age.keys(), amount_by_age.values())
plt.title('Amount Spent by Age', y=1.05, fontsize=14, fontweight='bold')
plt.xlabel('Age', fontweight='bold')
plt.ylabel('amount Spent', fontweight='bold');

# %% [markdown]
# *The amount spent corresponds to age distribution. Customers between 50 & 70 years spend the most.*

# %%
plt.figure(figsize=[18, 8.27])
base_color = sb.color_palette()[0]
#month_order = df_2020['month'].value_counts().index
sb.barplot(final_df.age, final_df.amount, hue = final_df.gender)
plt.title('Amount Spent by Age & Gender', y=1.05, fontsize=14, fontweight='bold')
plt.xlabel('Age', fontweight='bold')
plt.ylabel('Amount', fontweight='bold');

# %%
amount_by_age_gender = final_df.groupby(['gender', 'age'])['amount'].sum()
amount_by_age_gender
# Out:
# gender  age
# F       18      1116.82
#         19      2990.83
#         20      4452.94
#         21      5579.64
#         22      6388.99
#         23      3165.89
#         24      5368.55
#         25      4157.34
#         26      5178.99
#         27      3985.07
#         28      5633.70
#         29      6338.58
#         30      4435.68
#         31      2500.90
#         32      5430.00
#         33      5253.53
#         34      5102.91
#         35      5207.71
#         36      7346.77
#         37      8474.94
#         38      8741.49
#         39     10878.86
#         40      8510.30
#         41      7547.21
#         42      8374.48
#         43      9762.84
#         44      9894.74
#         45      9662.18
#         46     10379.94
#         47      9704.48
#                  ...
# O       58      1252.75
#         59       585.18
#         60      1306.78
#         61       627.40
#         62       944.90
#         63       576.85
#         64       171.15
#         65        57.72
#         66       620.23
#         67      1263.25
#         68       505.53
#         69        58.96
#         70        28.29
#         71       173.62
#         72        93.47
#         73      1163.20
#         74       542.47
#         75       228.55
#         76       231.25
#         77       737.12
#         79       180.06
#         80        15.83
#         81        18.56
#         82        82.14
#         84       120.92
#         85        97.80
#         89       296.48
#         90        80.85
#         92       173.08
#         100      197.91
# Name: amount, Length: 233, dtype: float64

# %%
amount_by_age_gender['F'].hist()
amount_by_age_gender['M'].hist()
plt.legend()

# %%
# Assigning names to 'offer received', 'offer viewed', 'offer completed', and 'transaction' to facilitate recall and comparison
offer_received = final_df.event == 'offer received'
offer_viewed = final_df.event == 'offer viewed'
offer_completed = final_df.event == 'offer completed'
transaction = final_df.event == 'transaction'

# %%
final_df[offer_received].count()
# Out:
# person              66501
# age                 66501
# gender              66501
# income              66501
# became_member_on    66501
# event               66501
# event_time          66501
# offer_type          66501
# offer_reward        66501
# earned_reward           0
# amount                  0
# offer_id            66501
# channels            66501
# difficulty          66501
# offer_duration      66501
# dtype: int64

# %% [markdown]
# *66501 clients of known demographics received offers.*

# %%
# Compare genders of those who received offers.
plt.figure(figsize=[14.70, 8.27])
final_df.gender[offer_received].hist()
plt.title('Gender Comparison of Clients Who Received Offers')
plt.xlabel('Gender')
plt.ylabel('Client Number');

# %%
final_df.gender[offer_received].value_counts()
# Out:
# M    38129
# F    27456
# O      916
# Name: gender, dtype: int64

# %%
final_df[offer_received].groupby(['gender', 'offer_type']).count()
# Out:
#                       person    age  income  became_member_on  event  \
# gender offer_type
# F      bogo            10975  10975   10975             10975  10975
#        discount        10943  10943   10943             10943  10943
#        informational    5538   5538    5538              5538   5538
# M      bogo            15208  15208   15208             15208  15208
#        discount        15354  15354   15354             15354  15354
#        informational    7567   7567    7567              7567   7567
# O      bogo              354    354     354               354    354
#        discount          367    367     367               367    367
#        informational     195    195     195               195    195
#
#                       event_time  offer_reward  earned_reward  amount  \
# gender offer_type
# F      bogo                10975         10975              0       0
#        discount            10943         10943              0       0
#        informational        5538          5538              0       0
# M      bogo                15208         15208              0       0
#        discount            15354         15354              0       0
#        informational        7567          7567              0       0
# O      bogo                  354           354              0       0
#        discount              367           367              0       0
#        informational         195           195              0       0
#
#                       offer_id  channels  difficulty  offer_duration
# gender offer_type
# F      bogo              10975     10975       10975           10975
#        discount          10943     10943       10943           10943
#        informational      5538      5538        5538            5538
# M      bogo              15208     15208       15208           15208
#        discount          15354     15354       15354           15354
#        informational      7567      7567        7567            7567
# O      bogo                354       354         354             354
#        discount            367       367         367             367
#        informational       195       195         195             195

# %%
# Creating a pie chart of offers received by female clients
plt.figure(figsize=[14.7,  8.27])
plt.pie(final_df[offer_received].groupby(['gender', 'offer_type']).count()[:3].person,
       labels = ['bogo', 'discount', 'informational'],
       autopct = '%1.1f%%', # To show percent on plot. 1.1  formats the percentage to the tenth place. 
       shadow=True,
       explode=(0.05, 0.05, 0.05)
       )
plt.title('Percentage of Offers Received by Female Clients')
plt.axis('equal'); # By default, matplotlib creates pie charts with a tilt. This line remove this tilt

plt.figure(figsize=[14.7,  8.27])
plt.pie(final_df[offer_received].groupby(['gender', 'offer_type']).count()[3:6].person,
       labels = ['bogo', 'discount', 'informational'],
       autopct = '%1.1f%%', # To show percent on plot. 1.1  formats the percentage to the tenth place. 
       shadow=True,
       explode=(0.05, 0.05, 0.05)
       )
plt.title('Percentage of Offers Received by Male Clients')
plt.axis('equal'); # By default, matplotlib creates pie charts with a tilt. This line remove this tilt

# %% [markdown]
# *Almost the same percent of offer types was received by both males and females*

# %%
final_df[offer_viewed].count()
# Out:
# person              49860
# age                 49860
# gender              49860
# income              49860
# became_member_on    49860
# event               49860
# event_time          49860
# offer_type          49860
# offer_reward        49860
# earned_reward           0
# amount                  0
# offer_id            49860
# channels            49860
# difficulty          49860
# offer_duration      49860
# dtype: int64

# %% [markdown]
# *Only 49860 of clients who received offers viewed them. That's 74.9%*

# %%
# Compare genders of those who viewed offers.
plt.figure(figsize=[14.70, 8.27])
final_df.gender[offer_viewed].hist()
plt.legend()
plt.title('Gender Comparison of Clients Who Viewed Offers')
plt.xlabel('Gender')
plt.ylabel('Client Number');

# %%
final_df.gender[offer_viewed].value_counts()
# Out:
# M    28301
# F    20786
# O      773
# Name: gender, dtype: int64

# %%
final_df[offer_viewed].groupby(['gender', 'offer_type']).count()
# Out:
#                       person    age  income  became_member_on  event  \
# gender offer_type
# F      bogo             9143   9143    9143              9143   9143
#        discount         7733   7733    7733              7733   7733
#        informational    3910   3910    3910              3910   3910
# M      bogo            12581  12581   12581             12581  12581
#        discount        10431  10431   10431             10431  10431
#        informational    5289   5289    5289              5289   5289
# O      bogo              315    315     315               315    315
#        discount          297    297     297               297    297
#        informational     161    161     161               161    161
#
#                       event_time  offer_reward  earned_reward  amount  \
# gender offer_type
# F      bogo                 9143          9143              0       0
#        discount             7733          7733              0       0
#        informational        3910          3910              0       0
# M      bogo                12581         12581              0       0
#        discount            10431         10431              0       0
#        informational        5289          5289              0       0
# O      bogo                  315           315              0       0
#        discount              297           297              0       0
#        informational         161           161              0       0
#
#                       offer_id  channels  difficulty  offer_duration
# gender offer_type
# F      bogo               9143      9143        9143            9143
#        discount           7733      7733        7733            7733
#        informational      3910      3910        3910            3910
# M      bogo              12581     12581       12581           12581
#        discount          10431     10431       10431           10431
#        informational      5289      5289        5289            5289
# O      bogo                315       315         315             315
#        discount            297       297         297             297
#        informational       161       161         161             161

# %%
# Creating a pie chart of offers viewed by female clients
plt.figure(figsize=[14.7,  8.27])
plt.pie(final_df[offer_viewed].groupby(['gender', 'offer_type']).count()[:3].person,
       labels = ['bogo', 'discount', 'informational'],
       autopct = '%1.1f%%', # To show percent on plot. 1.1  formats the percentage to the tenth place. 
       shadow=True,
       explode=(0.05, 0.05, 0.05)
       )
plt.title('Percentage of Offers Viewed by Female Clients')
plt.axis('equal'); # By default, matplotlib creates pie charts with a tilt. This line remove this tilt

# Creating a pie chart of offers viewed by male clients
plt.figure(figsize=[14.7,  8.27])
plt.pie(final_df[offer_viewed].groupby(['gender', 'offer_type']).count()[3:6].person,
       labels = ['bogo', 'discount', 'informational'],
       autopct = '%1.1f%%', # To show percent on plot. 1.1  formats the percentage to the tenth place. 
       shadow=True,
       explode=(0.05, 0.05, 0.05)
       )
plt.title('Percentage of Offers Viewed by Male Clients')
plt.axis('equal'); # By default, matplotlib creates pie charts with a tilt. This line remove this tilt

# %% [markdown]
# *Almost the same percent of offer types was viewed by both males and females*

# %%
final_df[offer_completed].count()
# Out:
# person              32444
# age                 32444
# gender              32444
# income              32444
# became_member_on    32444
# event               32444
# event_time          32444
# offer_type          32444
# offer_reward        32444
# earned_reward       32444
# amount                  0
# offer_id            32444
# channels            32444
# difficulty          32444
# offer_duration      32444
# dtype: int64

# %% [markdown]
# *Only 32444 of the received offers were completed.That's 48.79%*

# %%
# Compare genders of those who completed offers.
plt.figure(figsize=[14.70, 8.27])
final_df.gender[offer_completed].hist()
plt.legend()
plt.title('Gender Comparison of Clients Who Completed Offers')
plt.xlabel('Gender')
plt.ylabel('Client Number');

# %%
final_df.gender[offer_completed].value_counts()
# Out:
# M    16466
# F    15477
# O      501
# Name: gender, dtype: int64

# %%
print ('Percent of females who completed offers of those who received offers = ', final_df.gender[offer_completed].value_counts()[1]/
final_df.gender[offer_received].value_counts()[1]*100, '%')
# Out:
# Percent of females who completed offers of those who received offers =  56.3701923077 %

# %%
print ('Percent of males who completed offers of those who received offers = ', final_df.gender[offer_completed].value_counts()[0]/
final_df.gender[offer_received].value_counts()[0]*100, '%')
# Out:
# Percent of males who completed offers of those who received offers =  43.1849773139 %

# %% [markdown]
# *Number of male customers who received, viewed, and completed offers is more than females.*
#
# *Number of female customers who completed offers is very close to male customers*
#
# *Percent of females who completed offers if higher than that of males. Therefore the company should focus on sending more offers to females.*
#
# *Other gender doesn't have significant influence on analysis results and can be neglected through the whole analysis process.*

# %%
# Compare genders of those who received offers to those who completed offers.
plt.figure(figsize=[14.70, 8.27])
final_df.gender[offer_received].hist(alpha = 0.5, label = 'Offer Received')
final_df.gender[offer_completed].hist(alpha = 0.5, label = 'Offer Completed')
plt.legend()
plt.title('Comparison Between Customers Who Received Offers to Those Who Completed According to Gender')
plt.xlabel('Gender')
plt.ylabel('Customer Number');

# %%
final_df[offer_completed].groupby(['gender', 'offer_type']).count()
# Out:
#                    person   age  income  became_member_on  event  event_time  \
# gender offer_type
# F      bogo          7501  7501    7501              7501   7501        7501
#        discount      7976  7976    7976              7976   7976        7976
# M      bogo          7512  7512    7512              7512   7512        7512
#        discount      8954  8954    8954              8954   8954        8954
# O      bogo           245   245     245               245    245         245
#        discount       256   256     256               256    256         256
#
#                    offer_reward  earned_reward  amount  offer_id  channels  \
# gender offer_type
# F      bogo                7501           7501       0      7501      7501
#        discount            7976           7976       0      7976      7976
# M      bogo                7512           7512       0      7512      7512
#        discount            8954           8954       0      8954      8954
# O      bogo                 245            245       0       245       245
#        discount             256            256       0       256       256
#
#                    difficulty  offer_duration
# gender offer_type
# F      bogo              7501            7501
#        discount          7976            7976
# M      bogo              7512            7512
#        discount          8954            8954
# O      bogo               245             245
#        discount           256             256

# %%
# Creating a pie chart of offers completed by female clients
plt.figure(figsize=[14.7,  8.27])
plt.pie(final_df[offer_completed].groupby(['gender', 'offer_type']).count()[:2].person,
       labels = ['bogo', 'discount'],
       autopct = '%1.1f%%', # To show percent on plot. 1.1  formats the percentage to the tenth place. 
       shadow=True,
       explode=(0.05, 0.05)
       )
plt.title('Percentage of Offers Completed by Female Clients')
plt.axis('equal'); # By default, matplotlib creates pie charts with a tilt. This line remove this tilt

# Creating a pie chart of offers completed by male clients
plt.figure(figsize=[14.7,  8.27])
plt.pie(final_df[offer_completed].groupby(['gender', 'offer_type']).count()[2:4].person,
       labels = ['bogo', 'discount'],
       autopct = '%1.1f%%', # To show percent on plot. 1.1  formats the percentage to the tenth place. 
       shadow=True,
       explode=(0.05, 0.05)
       )
plt.title('Percentage of Offers Completed by Male Clients')
plt.axis('equal'); # By default, matplotlib creates pie charts with a tilt. This line remove this tilt

# %% [markdown]
# *Both males and females responded more to discount offers.*
#
# *More males (54.4%) responded to discount offers than females (51.5%).*
#
# *More females (48.5%) responded to bogo offers than males (45.6%).*

# %% [markdown]
# <a id='refining'></a>
# ### C. Refinement

# %%
# Repeat previous process with age

# %%
final_df[offer_completed].groupby(['age', 'offer_type', 'gender']).count()
# Out:
#                        person  income  became_member_on  event  event_time  \
# age offer_type gender
# 18  bogo       F           15      15                15     15          15
#                M           41      41                41     41          41
#     discount   F           15      15                15     15          15
#                M           58      58                58     58          58
# 19  bogo       F           32      32                32     32          32
#                M           53      53                53     53          53
#     discount   F           22      22                22     22          22
#                M           84      84                84     84          84
# 20  bogo       F           40      40                40     40          40
#                M           59      59                59     59          59
#                O            4       4                 4      4           4
#     discount   F           35      35                35     35          35
#                M           75      75                75     75          75
#                O            3       3                 3      3           3
# 21  bogo       F           49      49                49     49          49
#                M           58      58                58     58          58
#                O            1       1                 1      1           1
#     discount   F           56      56                56     56          56
#                M           74      74                74     74          74
#                O            3       3                 3      3           3
# 22  bogo       F           41      41                41     41          41
#                M           50      50                50     50          50
#                O            1       1                 1      1           1
#     discount   F           51      51                51     51          51
#                M           67      67                67     67          67
#                O            1       1                 1      1           1
# 23  bogo       F           23      23                23     23          23
#                M           72      72                72     72          72
#     discount   F           40      40                40     40          40
#                M           91      91                91     91          91
# ...                       ...     ...               ...    ...         ...
# 94  bogo       M           22      22                22     22          22
#     discount   F           16      16                16     16          16
#                M           24      24                24     24          24
# 95  bogo       F           20      20                20     20          20
#                M            6       6                 6      6           6
#     discount   F           19      19                19     19          19
#                M            4       4                 4      4           4
# 96  bogo       F            9       9                 9      9           9
#                M            3       3                 3      3           3
#     discount   F            9       9                 9      9           9
#                M            6       6                 6      6           6
# 97  bogo       F            9       9                 9      9           9
#                M            5       5                 5      5           5
#     discount   F            5       5                 5      5           5
#                M            8       8                 8      8           8
# 98  bogo       F            1       1                 1      1           1
#                M            2       2                 2      2           2
#     discount   F            1       1                 1      1           1
#                M            2       2                 2      2           2
# 99  bogo       F            4       4                 4      4           4
#                M            4       4                 4      4           4
#     discount   F            8       8                 8      8           8
#                M            2       2                 2      2           2
# 100 bogo       F           12      12                12     12          12
#                M            3       3                 3      3           3
#                O            2       2                 2      2           2
#     discount   F           12      12                12     12          12
#                M            4       4                 4      4           4
# 101 bogo       F            2       2                 2      2           2
#     discount   F           10      10                10     10          10
#
#                        offer_reward  earned_reward  amount  offer_id  \
# age offer_type gender
# 18  bogo       F                 15             15       0        15
#                M                 41             41       0        41
#     discount   F                 15             15       0        15
#                M                 58             58       0        58
# 19  bogo       F                 32             32       0        32
#                M                 53             53       0        53
#     discount   F                 22             22       0        22
#                M                 84             84       0        84
# 20  bogo       F                 40             40       0        40
#                M                 59             59       0        59
#                O                  4              4       0         4
#     discount   F                 35             35       0        35
#                M                 75             75       0        75
#                O                  3              3       0         3
# 21  bogo       F                 49             49       0        49
#                M                 58             58       0        58
#                O                  1              1       0         1
#     discount   F                 56             56       0        56
#                M                 74             74       0        74
#                O                  3              3       0         3
# 22  bogo       F                 41             41       0        41
#                M                 50             50       0        50
#                O                  1              1       0         1
#     discount   F                 51             51       0        51
#                M                 67             67       0        67
#                O                  1              1       0         1
# 23  bogo       F                 23             23       0        23
#                M                 72             72       0        72
#     discount   F                 40             40       0        40
#                M                 91             91       0        91
# ...                             ...            ...     ...       ...
# 94  bogo       M                 22             22       0        22
#     discount   F                 16             16       0        16
#                M                 24             24       0        24
# 95  bogo       F                 20             20       0        20
#                M                  6              6       0         6
#     discount   F                 19             19       0        19
#                M                  4              4       0         4
# 96  bogo       F                  9              9       0         9
#                M                  3              3       0         3
#     discount   F                  9              9       0         9
#                M                  6              6       0         6
# 97  bogo       F                  9              9       0         9
#                M                  5              5       0         5
#     discount   F                  5              5       0         5
#                M                  8              8       0         8
# 98  bogo       F                  1              1       0         1
#                M                  2              2       0         2
#     discount   F                  1              1       0         1
#                M                  2              2       0         2
# 99  bogo       F                  4              4       0         4
#                M                  4              4       0         4
#     discount   F                  8              8       0         8
#                M                  2              2       0         2
# 100 bogo       F                 12             12       0        12
#                M                  3              3       0         3
#                O                  2              2       0         2
#     discount   F                 12             12       0        12
#                M                  4              4       0         4
# 101 bogo       F                  2              2       0         2
#     discount   F                 10             10       0        10
#
#                        channels  difficulty  offer_duration
# age offer_type gender
# 18  bogo       F             15          15              15
#                M             41          41              41
#     discount   F             15          15              15
#                M             58          58              58
# 19  bogo       F             32          32              32
#                M             53          53              53
#     discount   F             22          22              22
#                M             84          84              84
# 20  bogo       F             40          40              40
#                M             59          59              59
#                O              4           4               4
#     discount   F             35          35              35
#                M             75          75              75
#                O              3           3               3
# 21  bogo       F             49          49              49
#                M             58          58              58
#                O              1           1               1
#     discount   F             56          56              56
#                M             74          74              74
#                O              3           3               3
# 22  bogo       F             41          41              41
#                M             50          50              50
#                O              1           1               1
#     discount   F             51          51              51
#                M             67          67              67
#                O              1           1               1
# 23  bogo       F             23          23              23
#                M             72          72              72
#     discount   F             40          40              40
#                M             91          91              91
# ...                         ...         ...             ...
# 94  bogo       M             22          22              22
#     discount   F             16          16              16
#                M             24          24              24
# 95  bogo       F             20          20              20
#                M              6           6               6
#     discount   F             19          19              19
#                M              4           4               4
# 96  bogo       F              9           9               9
#                M              3           3               3
#     discount   F              9           9               9
#                M              6           6               6
# 97  bogo       F              9           9               9
#                M              5           5               5
#     discount   F              5           5               5
#                M              8           8               8
# 98  bogo       F              1           1               1
#                M              2           2               2
#     discount   F              1           1               1
#                M              2           2               2
# 99  bogo       F              4           4               4
#                M              4           4               4
#     discount   F              8           8               8
#                M              2           2               2
# 100 bogo       F             12          12              12
#                M              3           3               3
#                O              2           2               2
#     discount   F             12          12              12
#                M              4           4               4
# 101 bogo       F              2           2               2
#     discount   F             10          10              10
#
# [447 rows x 12 columns]

# %%
# scatterplot - duration and month - by user type

plt.figure(figsize=[14.70, 8.27])
sb.stripplot(data = final_df[offer_completed], x = 'gender', y = 'age', hue = 'offer_type',
jitter = 0.35, dodge = True)
plt.legend(loc= 'center left', bbox_to_anchor = (1, 0.5), title = 'Offer Type')
plt.title('Completed Offers by Age, Offer Type, & Gender', y=1.05, fontsize=14, fontweight='bold')
plt.xlabel('Gender', fontweight='bold')
plt.ylabel('Age', fontweight='bold');

# %%
#scatter plot between income and purchase

# %%
plt.scatter(final_df.income[transaction], final_df.amount[transaction])
plt.title('Relationship between Inome and Purchase')
plt.xlabel('Income')
plt.ylabel('Purchase Amount');

# %% [markdown]
# *Interesting! It seems there is a group of people whose purchse habbits don't change whith the change of their income.*

# %%
final_df[transaction]
# Out:
#                                   person  age gender    income  \
# 0       0610b486422d4921ae7d2bf64640c50b   55      F  112000.0
# 1       0610b486422d4921ae7d2bf64640c50b   55      F  112000.0
# 4       0610b486422d4921ae7d2bf64640c50b   55      F  112000.0
# 8       78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 10      78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 13      78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 14      78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 15      78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 19      78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 22      78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0
# 26      e2127556f4f64592b11af22de27a7932   68      M   70000.0
# 27      e2127556f4f64592b11af22de27a7932   68      M   70000.0
# 33      e2127556f4f64592b11af22de27a7932   68      M   70000.0
# 38      389bc3fa690240e798340f5a15918d5c   65      M   53000.0
# 46      389bc3fa690240e798340f5a15918d5c   65      M   53000.0
# 53      389bc3fa690240e798340f5a15918d5c   65      M   53000.0
# 59      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 62      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 63      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 65      2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0
# 70      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 75      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 78      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 79      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 80      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 83      aa4862eba776480b8bb9c68455b8c2e1   61      F   57000.0
# 86      e12aeaf2d47d42479ea1c4ac3d8286c6   26      M   46000.0
# 87      e12aeaf2d47d42479ea1c4ac3d8286c6   26      M   46000.0
# 89      e12aeaf2d47d42479ea1c4ac3d8286c6   26      M   46000.0
# 91      e12aeaf2d47d42479ea1c4ac3d8286c6   26      M   46000.0
# ...                                  ...  ...    ...       ...
# 272709  2cb4f97358b841b9a9773a7aa05a9d77   61      M   72000.0
# 272712  2cb4f97358b841b9a9773a7aa05a9d77   61      M   72000.0
# 272715  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272717  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272718  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272720  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272721  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272722  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272723  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272724  01d26f638c274aa0b965d24cefe3183f   49      M   73000.0
# 272725  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272726  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272727  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272730  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272731  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272733  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272735  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272737  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272738  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272740  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272742  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272745  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272746  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272747  9dc1421481194dcd9400aec7c9ae6366   83      F   50000.0
# 272750  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272752  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272753  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272756  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272758  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
# 272761  e4052622e5ba45a8b96b59aba68cf068   62      F   82000.0
#
#         became_member_on        event  event_time offer_type  offer_reward  \
# 0               20170715  transaction          18        NaN           NaN
# 1               20170715  transaction         144        NaN           NaN
# 4               20170715  transaction         528        NaN           NaN
# 8               20170509  transaction         132        NaN           NaN
# 10              20170509  transaction         144        NaN           NaN
# 13              20170509  transaction         222        NaN           NaN
# 14              20170509  transaction         240        NaN           NaN
# 15              20170509  transaction         378        NaN           NaN
# 19              20170509  transaction         510        NaN           NaN
# 22              20170509  transaction         534        NaN           NaN
# 26              20180426  transaction         288        NaN           NaN
# 27              20180426  transaction         294        NaN           NaN
# 33              20180426  transaction         522        NaN           NaN
# 38              20180209  transaction          60        NaN           NaN
# 46              20180209  transaction         498        NaN           NaN
# 53              20180209  transaction         600        NaN           NaN
# 59              20171111  transaction         216        NaN           NaN
# 62              20171111  transaction         378        NaN           NaN
# 63              20171111  transaction         456        NaN           NaN
# 65              20171111  transaction         570        NaN           NaN
# 70              20170911  transaction         210        NaN           NaN
# 75              20170911  transaction         426        NaN           NaN
# 78              20170911  transaction         456        NaN           NaN
# 79              20170911  transaction         498        NaN           NaN
# 80              20170911  transaction         516        NaN           NaN
# 83              20170911  transaction         630        NaN           NaN
# 86              20140213  transaction          36        NaN           NaN
# 87              20140213  transaction          90        NaN           NaN
# 89              20140213  transaction         198        NaN           NaN
# 91              20140213  transaction         360        NaN           NaN
# ...                  ...          ...         ...        ...           ...
# 272709          20180713  transaction         420        NaN           NaN
# 272712          20180713  transaction         654        NaN           NaN
# 272715          20170126  transaction         204        NaN           NaN
# 272717          20170126  transaction         372        NaN           NaN
# 272718          20170126  transaction         378        NaN           NaN
# 272720          20170126  transaction         396        NaN           NaN
# 272721          20170126  transaction         402        NaN           NaN
# 272722          20170126  transaction         480        NaN           NaN
# 272723          20170126  transaction         576        NaN           NaN
# 272724          20170126  transaction         672        NaN           NaN
# 272725          20160307  transaction          24        NaN           NaN
# 272726          20160307  transaction         150        NaN           NaN
# 272727          20160307  transaction         228        NaN           NaN
# 272730          20160307  transaction         348        NaN           NaN
# 272731          20160307  transaction         360        NaN           NaN
# 272733          20160307  transaction         372        NaN           NaN
# 272735          20160307  transaction         414        NaN           NaN
# 272737          20160307  transaction         426        NaN           NaN
# 272738          20160307  transaction         504        NaN           NaN
# 272740          20160307  transaction         522        NaN           NaN
# 272742          20160307  transaction         594        NaN           NaN
# 272745          20160307  transaction         636        NaN           NaN
# 272746          20160307  transaction         660        NaN           NaN
# 272747          20160307  transaction         684        NaN           NaN
# 272750          20170722  transaction          54        NaN           NaN
# 272752          20170722  transaction          84        NaN           NaN
# 272753          20170722  transaction          96        NaN           NaN
# 272756          20170722  transaction         480        NaN           NaN
# 272758          20170722  transaction         486        NaN           NaN
# 272761          20170722  transaction         690        NaN           NaN
#
#         earned_reward  amount offer_id channels  difficulty  offer_duration
# 0                 NaN   21.51      NaN      NaN         NaN             NaN
# 1                 NaN   32.28      NaN      NaN         NaN             NaN
# 4                 NaN   23.22      NaN      NaN         NaN             NaN
# 8                 NaN   19.89      NaN      NaN         NaN             NaN
# 10                NaN   17.78      NaN      NaN         NaN             NaN
# 13                NaN   19.67      NaN      NaN         NaN             NaN
# 14                NaN   29.72      NaN      NaN         NaN             NaN
# 15                NaN   23.93      NaN      NaN         NaN             NaN
# 19                NaN   21.72      NaN      NaN         NaN             NaN
# 22                NaN   26.56      NaN      NaN         NaN             NaN
# 26                NaN   17.88      NaN      NaN         NaN             NaN
# 27                NaN   21.43      NaN      NaN         NaN             NaN
# 33                NaN   18.42      NaN      NaN         NaN             NaN
# 38                NaN    9.54      NaN      NaN         NaN             NaN
# 46                NaN   15.63      NaN      NaN         NaN             NaN
# 53                NaN   11.26      NaN      NaN         NaN             NaN
# 59                NaN    2.32      NaN      NaN         NaN             NaN
# 62                NaN    5.29      NaN      NaN         NaN             NaN
# 63                NaN    7.14      NaN      NaN         NaN             NaN
# 65                NaN    0.87      NaN      NaN         NaN             NaN
# 70                NaN   12.33      NaN      NaN         NaN             NaN
# 75                NaN   15.95      NaN      NaN         NaN             NaN
# 78                NaN   23.30      NaN      NaN         NaN             NaN
# 79                NaN   10.08      NaN      NaN         NaN             NaN
# 80                NaN   11.33      NaN      NaN         NaN             NaN
# 83                NaN   12.56      NaN      NaN         NaN             NaN
# 86                NaN   11.58      NaN      NaN         NaN             NaN
# 87                NaN    1.36      NaN      NaN         NaN             NaN
# 89                NaN    1.16      NaN      NaN         NaN             NaN
# 91                NaN    7.85      NaN      NaN         NaN             NaN
# ...               ...     ...      ...      ...         ...             ...
# 272709            NaN    6.46      NaN      NaN         NaN             NaN
# 272712            NaN    2.42      NaN      NaN         NaN             NaN
# 272715            NaN    3.30      NaN      NaN         NaN             NaN
# 272717            NaN    7.58      NaN      NaN         NaN             NaN
# 272718            NaN    8.26      NaN      NaN         NaN             NaN
# 272720            NaN    5.93      NaN      NaN         NaN             NaN
# 272721            NaN    1.74      NaN      NaN         NaN             NaN
# 272722            NaN    2.16      NaN      NaN         NaN             NaN
# 272723            NaN    6.61      NaN      NaN         NaN             NaN
# 272724            NaN    4.16      NaN      NaN         NaN             NaN
# 272725            NaN    6.49      NaN      NaN         NaN             NaN
# 272726            NaN   11.51      NaN      NaN         NaN             NaN
# 272727            NaN    6.81      NaN      NaN         NaN             NaN
# 272730            NaN    9.49      NaN      NaN         NaN             NaN
# 272731            NaN   10.75      NaN      NaN         NaN             NaN
# 272733            NaN   13.10      NaN      NaN         NaN             NaN
# 272735            NaN   11.03      NaN      NaN         NaN             NaN
# 272737            NaN   13.13      NaN      NaN         NaN             NaN
# 272738            NaN   17.26      NaN      NaN         NaN             NaN
# 272740            NaN   31.60      NaN      NaN         NaN             NaN
# 272742            NaN   12.57      NaN      NaN         NaN             NaN
# 272745            NaN   14.55      NaN      NaN         NaN             NaN
# 272746            NaN   20.27      NaN      NaN         NaN             NaN
# 272747            NaN   11.11      NaN      NaN         NaN             NaN
# 272750            NaN   21.55      NaN      NaN         NaN             NaN
# 272752            NaN   25.19      NaN      NaN         NaN             NaN
# 272753            NaN   21.53      NaN      NaN         NaN             NaN
# 272756            NaN   30.57      NaN      NaN         NaN             NaN
# 272758            NaN   19.47      NaN      NaN         NaN             NaN
# 272761            NaN   24.71      NaN      NaN         NaN             NaN
#
# [123957 rows x 15 columns]

# %%
final_df.income[transaction].value_counts().sort_index(ascending=False)
# Out:
# 120000.0      86
# 119000.0     326
# 118000.0     393
# 117000.0     219
# 116000.0     280
# 115000.0     306
# 114000.0     370
# 113000.0     301
# 112000.0     239
# 111000.0     311
# 110000.0     354
# 109000.0     346
# 108000.0     331
# 107000.0     236
# 106000.0     349
# 105000.0     362
# 104000.0     331
# 103000.0     390
# 102000.0     309
# 101000.0     288
# 100000.0     525
# 99000.0      817
# 98000.0      681
# 97000.0      781
# 96000.0      827
# 95000.0      814
# 94000.0      726
# 93000.0      825
# 92000.0      856
# 91000.0      618
#             ...
# 59000.0     2163
# 58000.0     2093
# 57000.0     2557
# 56000.0     2461
# 55000.0     2297
# 54000.0     2456
# 53000.0     2516
# 52000.0     2575
# 51000.0     2369
# 50000.0     2386
# 49000.0     1590
# 48000.0     1777
# 47000.0     1919
# 46000.0     1784
# 45000.0     1974
# 44000.0     1794
# 43000.0     1578
# 42000.0     1778
# 41000.0     1987
# 40000.0     2014
# 39000.0     2126
# 38000.0     1843
# 37000.0     2140
# 36000.0     2015
# 35000.0     2092
# 34000.0     2047
# 33000.0     2120
# 32000.0     2261
# 31000.0     2236
# 30000.0      874
# Name: income, Length: 91, dtype: int64

# %%
final_df.amount[transaction].value_counts().sort_index(ascending=False)
# Out:
# 1062.28      1
# 1015.73      1
# 1001.85      1
# 989.34       1
# 977.78       1
# 966.24       1
# 962.10       1
# 961.21       1
# 957.15       1
# 947.43       1
# 943.40       1
# 943.33       1
# 936.94       1
# 922.65       1
# 920.01       1
# 919.16       1
# 918.02       1
# 901.37       1
# 881.35       1
# 872.77       1
# 871.51       1
# 868.07       1
# 863.32       1
# 862.16       1
# 855.31       1
# 850.36       1
# 845.01       1
# 841.45       1
# 841.06       1
# 840.28       1
#           ...
# 0.34        55
# 0.33        70
# 0.32        70
# 0.31        73
# 0.30        68
# 0.29        72
# 0.28        55
# 0.27        73
# 0.26        75
# 0.25        53
# 0.24        73
# 0.23        70
# 0.22        63
# 0.21        58
# 0.20        59
# 0.19        55
# 0.18        50
# 0.17        51
# 0.16        64
# 0.15        58
# 0.14        57
# 0.13        50
# 0.12        44
# 0.11        50
# 0.10        36
# 0.09        42
# 0.08        52
# 0.07        37
# 0.06        43
# 0.05       133
# Name: amount, Length: 5036, dtype: int64
